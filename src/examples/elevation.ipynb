# %%
from odc.geo.cog import write_cog

from linz_s3_utils.elevation import ElevationClient

# %%
elevation_client = ElevationClient()

# %%
da = elevation_client.load_lidar_dem(resolution=1000)

da

# %%
write_cog(da, "lidar_dem_1000m.tif", overwrite=True)

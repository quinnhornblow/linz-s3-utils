# %%
from linz_s3_utils.elevation import ElevationClient

# %%
elevation_client = ElevationClient()

# %%
elevation_client.load_latest_lidar()
# Out:
# c:\Users\quho\repositories\_personal\linz-s3-utils\.venv\Lib\site-packages\pystac_client\client.py:446: FallbackToPystac: Falling back to pystac. This might be slow.
#   self._warn_about_fallback("COLLECTIONS", "FEATURES")
# <xarray.Dataset> Size: 23GB
# Dimensions:      (y: 14761, x: 9842, time: 39)
# Coordinates:
#   * y            (y) float64 118kB 6.234e+06 6.234e+06 ... 4.758e+06 4.758e+06
#   * x            (x) float64 79kB 1.132e+06 1.132e+06 ... 2.116e+06 2.116e+06
#   * time         (time) datetime64[us] 312B 2008-04-30T12:00:00 ... 2025-02-0...
#     spatial_ref  int32 4B 2193
# Data variables:
#     visual       (time, y, x) float32 23GB nan nan nan nan ... nan nan nan nan

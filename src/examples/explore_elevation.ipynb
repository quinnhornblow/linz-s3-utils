# %%
from linz_s3_utils.io import list_elevation_capture_areas, list_elevation_directories

# %%
# Print unique directories under S3_ELEVATION_DIR that contain .tiff files.
for directory in list_elevation_directories():
    print(directory)

# %%
for capture_area in list_elevation_capture_areas():
    print(capture_area)
